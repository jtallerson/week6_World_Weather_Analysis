# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
coordinates[0:5]
# Out:
# [(62.166105170205384, 93.50346721456259),
#  (3.4285890982313134, 150.2993998143789),
#  (-85.93202013491137, 166.88086914796082),
#  (47.52021533990333, -164.40472496483298),
#  (-28.69179591587632, 7.922090472749943)]

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 750

# %%
import requests
import time

# Import the API key.
from config import weather_api_key

# %%
# init lists
longs = []
lats = []
temps = []
pressures = []
humids = []
cities_df = []
countries = []

base_url = "http://api.openweathermap.org/data/2.5/weather"

for city in cities:
    # Build query URL
    print(city)
    query_url = f"{base_url}?appid={weather_api_key}&q={city}&units=imperial"
    
    response = requests.get(query_url)

    if (response.status_code == 200):
        data = response.json()
        
        # data parsing
        try:
            long = data["coord"]["lon"]
            lat = data["coord"]["lat"]
            temp = data["main"]["temp"]
            pressure = data["main"]["pressure"]
            humid = data["main"]["humidity"]
            city_p = data["name"]
            country = data["sys"]["country"]

            # append to lists
            longs.append(long)
            lats.append(lat)
            temps.append(temp)
            pressures.append(pressure)
            humids.append(humid)
            cities_df.append(city_p)
            countries.append(country)
        except Exception as e:
            print(e)
            
            # append defaults to lists
            longs.append(np.nan)
            lats.append(np.nan)
            temps.append(np.nan)
            pressures.append(np.nan)
            humids.append(np.nan)
            cities_df.append(city)
            countries.append("")
    else:
        print(response.status_code)
        print(response.text)
        
    # sleep for one second
    time.sleep(1)
        
# build dataframe
df = pd.DataFrame()
df["City"] = cities_df
df["Countries"] = countries
df["Temp"] = temps
df["Humidity"] = humids
df["Pressure"] = pressures
df["Latitude"] = lats
df["Longitude"] = longs

df
# Out:
# severo-yeniseyskiy
# kavieng
# bluff
# bethel
# luderitz
# marshfield
# puerto ayora
# rabak
# nizhneyansk
# 404
# {"cod":"404","message":"city not found"}
# tevaitoa
# praia da vitoria
# hilo
# busselton
# yulara
# goderich
# albany
# codrington
# nanortalik
# stade
# xuddur
# upernavik
# punta arenas
# khani
# hermanus
# ushuaia
# new norfolk
# kodiak
# fayaoue
# vaini
# nanae
# aklavik
# merritt island
# cagayan de tawi-tawi
# 404
# {"cod":"404","message":"city not found"}
# grand river south east
# 404
# {"cod":"404","message":"city not found"}
# port alfred
# lebu
# aljezur
# jamestown
# karaul
# 404
# {"cod":"404","message":"city not found"}
# bandarbeyla
# katsuura
# illoqqortoormiut
# 404
# {"cod":"404","message":"city not found"}
# longyearbyen
# tumannyy
# 404
# {"cod":"404","message":"city not found"}
# rikitea
# taolanaro
# 404
# {"cod":"404","message":"city not found"}
# buckeye
# barrow
# saba
# mataura
# port hedland
# takhatpur
# havelock
# la ronge
# barentsburg
# 404
# {"cod":"404","message":"city not found"}
# avarua
# hobart
# richards bay
# turbe
# cidreira
# port lincoln
# clyde river
# quatre cocos
# chokurdakh
# ous
# gannan
# attawapiskat
# 404
# {"cod":"404","message":"city not found"}
# tuktoyaktuk
# biak
# poum
# fukue
# alexandria
# belmonte
# cockburn town
# pozo colorado
# mitu
# waterloo
# bambous virieux
# aksarka
# mar del plata
# soledade
# norman wells
# hamilton
# kaitangata
# dikson
# kristiansund
# celestun
# flekkefjord
# butaritari
# north bend
# ilhabela
# tarudant
# 404
# {"cod":"404","message":"city not found"}
# mys shmidta
# 404
# {"cod":"404","message":"city not found"}
# ngukurr
# 404
# {"cod":"404","message":"city not found"}
# taltal
# vila
# saint george
# bredasdorp
# belushya guba
# 404
# {"cod":"404","message":"city not found"}
# qaanaaq
# carnarvon
# san policarpo
# atuona
# grand forks
# khatanga
# vostok
# hobyo
# hithadhoo
# vitim
# nikolskoye
# matara
# arraial do cabo
# provideniya
# kathu
# tsaratanana
# zeya
# jiwani
# barinitas
# paamiut
# labuhan
# berkak
# jiroft
# 404
# {"cod":"404","message":"city not found"}
# guanica
# varnamo
# el tocuyo
# iqaluit
# kununurra
# cosala
# funtua
# yanan
# 404
# {"cod":"404","message":"city not found"}
# kaeo
# tommot
# boralday
# tessalit
# tiksi
# luganville
# flinders
# nusaybin
# halifax
# nouadhibou
# castro
# yellowknife
# baykit
# chuy
# manado
# nuzvid
# isangel
# cherskiy
# ketchikan
# porto murtinho
# maceio
# chegdomyn
# kuche
# 404
# {"cod":"404","message":"city not found"}
# airai
# adamas
# bend
# kibala
# saint-philippe
# pangoa
# umm lajj
# gamba
# rolim de moura
# 404
# {"cod":"404","message":"city not found"}
# kanigiri
# east london
# huaiyuan
# shahreza
# salinas
# kieta
# cape town
# jiuquan
# bengkulu
# severobaykalsk
# udachnyy
# puksoozero
# tiznit
# povenets
# sarkand
# kapaa
# lompoc
# sao filipe
# lorengau
# tuatapere
# pudozh
# port-cartier
# kahului
# sola
# sobolevo
# sal rei
# fushan
# kampene
# gravdal
# manta
# dongkan
# medicine hat
# itacarambi
# letterkenny
# vaitupu
# 404
# {"cod":"404","message":"city not found"}
# mersin
# paracuru
# jinchang
# buka
# coquimbo
# kyle of lochalsh
# 404
# {"cod":"404","message":"city not found"}
# georgetown
# san rafael
# alekseyevskoye
# pakxe
# axixa do tocantins
# 404
# {"cod":"404","message":"city not found"}
# victoria
# geraldton
# cabo san lucas
# torbay
# ganzhou
# faanui
# stephenville
# mahebourg
# victor harbor
# dingle
# stornoway
# sitka
# wajima
# lubango
# paka
# guerrero negro
# polewali
# thompson
# biberach
# lolua
# 404
# {"cod":"404","message":"city not found"}
# narsaq
# pevek
# tsihombe
# 404
# {"cod":"404","message":"city not found"}
# weyburn
# tezu
# ahipara
# vitorino freire
# harper
# constitucion
# oktyabrskiy
# talnakh
# jilotzingo
# puerto lleras
# emerald
# ribeira grande
# santo tomas
# crawley
# coihaique
# robertsport
# kommunisticheskiy
# duartina
# coruripe
# mount gambier
# zabid
# aykhal
# tarko-sale
# caninde de sao francisco
# pisco
# puro
# garissa
# suifenhe
# marcona
# 404
# {"cod":"404","message":"city not found"}
# ikeda
# atar
# porgera
# ancud
# laguna
# manavgat
# roald
# yar-sale
# caravelas
# souillac
# nuuk
# port elizabeth
# najran
# hofn
# conde
# saskylakh
# skibbereen
# sentyabrskiy
# 404
# {"cod":"404","message":"city not found"}
# ixtapa
# bowen
# urumqi
# chenzhou
# doctor pedro p. pena
# 404
# {"cod":"404","message":"city not found"}
# hami
# durban
# sosnogorsk
# verkhoyansk
# la plata
# ho
# 404
# {"cod":"404","message":"city not found"}
# westport
# basoko
# hrubieszow
# sao joao da barra
# shunyi
# kisanga
# yeppoon
# puerto escondido
# ilave
# sechura
# provost
# diffa
# alofi
# inuvik
# naze
# kabare
# broken hill
# bathsheba
# ponta do sol
# borazjan
# salalah
# socorro
# dandong
# benghazi
# karamea
# 404
# {"cod":"404","message":"city not found"}
# the pas
# buala
# grimshaw
# jiayuguan
# misawa
# vardo
# komsomolskiy
# nisia floresta
# rodrigues alves
# awbari
# pelym
# moramanga
# safwah
# 404
# {"cod":"404","message":"city not found"}
# krasnoarmeysk
# bandundu
# port hardy
# samusu
# 404
# {"cod":"404","message":"city not found"}
# bonthe
# kruisfontein
# lerwick
# show low
# kuruman
# meulaboh
# omsukchan
# ostrovnoy
# badgam
# 404
# {"cod":"404","message":"city not found"}
# palabuhanratu
# 404
# {"cod":"404","message":"city not found"}
# kulhudhuffushi
# bargal
# 404
# {"cod":"404","message":"city not found"}
# olafsvik
# arua
# moundou
# bourail
# abbeville
# chara
# mathbaria
# seoul
# yeniseysk
# esperance
# beringovskiy
# warrington
# itarema
# stromness
# yuryevets
# asau
# yorkton
# ushtobe
# sarangani
# amderma
# 404
# {"cod":"404","message":"city not found"}
# nikaia
# saint anthony
# rantepao
# beeville
# prince rupert
# lakes entrance
# dali
# great yarmouth
# zhengjiatun
# porto walter
# vila do maio
# babanusah
# 404
# {"cod":"404","message":"city not found"}
# verkh-usugli
# rocha
# toktogul
# namibe
# san lorenzo
# arman
# hasaki
# riyadh
# deogarh
# brae
# maniitsoq
# arlit
# konevo
# mitsamiouli
# mantua
# kharp
# crato
# cam pha
# 404
# {"cod":"404","message":"city not found"}
# malwan
# 404
# {"cod":"404","message":"city not found"}
# esna
# vanimo
# udimskiy
# champerico
# saldanha
# kaka
# grindavik
# palmas bellas
# mezen
# garbolovo
# quba
# pundaguitan
# tasiilaq
# panama city
# noumea
# bulgan
# khuzdar
# nadym
# lavrentiya
# ust-nera
# mokrous
# touros
# tamayo
# hambantota
# tevriz
# roma
# pyapon
# isla mujeres
# wanning
# karratha
# jiddah
# 404
# {"cod":"404","message":"city not found"}
# margate
# severo-kurilsk
# faya
# doha
# saleaula
# 404
# {"cod":"404","message":"city not found"}
# salekhard
# rakaia
# kleck
# 404
# {"cod":"404","message":"city not found"}
# mishan
# coracora
# saint combs
# 404
# {"cod":"404","message":"city not found"}
# liverpool
# kassala
# camacha
# bourges
# kemerovo
# kribi
# nurota
# vercheres
# panuco
# barcelona
# matveyev kurgan
# khuzhir
# batagay-alyta
# baguanos
# grand gaube
# havre-saint-pierre
# yumen
# nantong
# srednekolymsk
# lata
# ridgecrest
# komatipoort
# nongan
# yuzhno-kurilsk
# novonukutskiy
# mananjary
# mackay
# kamina
# yarmouth
# whitehorse
# mahajanga
# kenai
# broome
# sarai sidhu
# fairlie
# astana
# paiho
# 404
# {"cod":"404","message":"city not found"}
# calvinia
# carlyle
# bageshwar
# merauke
# uglich
# nara
# pedernales
# chom bung
# 404
# {"cod":"404","message":"city not found"}
# tadine
# tinskoy
# bur gabo
# 404
# {"cod":"404","message":"city not found"}
# altay
# klaksvik
# pacific grove
# sokoni
# san carlos
# ndele
# walvis bay
# kaa-khem
# acapulco
# berbera
# amboasary
# bambanglipuro
# muleba
# basco
# gizo
# shache
# koslan
# san cristobal
# xiaoyi
# urengoy
# suez
# korla
# ifanadiana
# torrington
# adrar
# sitges
# solnechnyy
# avera
# qeshm
# byron bay
# namatanai
# novomykolayivka
# gusau
# machilipatnam
# cap malheureux
# sao jose da coroa grande
# kavaratti
# choix
# chapais
# razole
# kalutara
# sur
# melo
# topolcani
# smoky lake
# varzea da palma
# san patricio
# cheremshan
# camargo
# doiwala
# aasiaat
# port alberni
# korgen
# kolvereid
# fortuna
# plaridel
# san quintin
# mercedes
# kudahuvadhoo
# miranda
# cedar city
# artyk
# 404
# {"cod":"404","message":"city not found"}
# toamasina
# alyangula
# la ferte-bernard
# husavik
# sedelnikovo
# 404
# {"cod":"404","message":"city not found"}
# ambulu
# doka
# ibadan
# plaster rock
# kostroma
# solaro
# sungairaya
# comodoro rivadavia
# nuqui
# hunza
# 404
# {"cod":"404","message":"city not found"}
# corvallis
# labuan
# abha
# tabuk
# lasa
# khandyga
# kolobrzeg
# grand-santi
# port keats
# xining
# sinnamary
# abiy adi
# 404
# {"cod":"404","message":"city not found"}
# kousseri
# melville
# kosonsoy
# borovoy
# bac lieu
# samarai
# caraballeda
# juba
# sokoto
# fairbanks
# epe
# akhtanizovskaya
# general pico
# hovd
# upata
# kodinsk
# tazovskiy
# betanzos
# suntar
# vila velha
# ciampino
# haines junction
# rock springs
# lhokseumawe
# opuwo
# dukhovnitskoye
# ulladulla
# villa bruzual
# carvin
# litherland
# shiyan
# mandalgovi
# cabedelo
# ginda
# college
# assiniboia
# zyryanka
# kamenskoye
# 404
# {"cod":"404","message":"city not found"}
# ust-kut
# redhakhol
# 404
# {"cod":"404","message":"city not found"}
# nagato
# clarence town
# buraydah
# banda aceh
# kollam
# limbang
# plettenberg bay
# nome
# kitimat
# yanaul
# kapit
# nizwa
# lagoa
# whitehaven
# tarakan
# utiroa
# 404
# {"cod":"404","message":"city not found"}
# den helder
# nemuro
# heidenheim
# sorvag
# 404
# {"cod":"404","message":"city not found"}
# lincoln
# vinh
# mahibadhoo
# nhulunbuy
# petersburg
# urgut
# thunder bay
# leshukonskoye
# ilulissat
# rockland
# campeche
# virginia beach
# barawe
# 404
# {"cod":"404","message":"city not found"}
# garachine
# antigonish
# berlevag
# amberley
# felidhoo
# 404
# {"cod":"404","message":"city not found"}
# chokwe
# chanute
# volchikha
# arecibo
# takoradi
# vestmanna
# nanchital
# butembo
# ambilobe
# kloulklubed
# mago
# ellenabad
# petropavlovsk-kamchatskiy
# yuci
# buin
# gushikawa
# chabahar
# zhigansk
# shestakovo
# yagodnoye
# camocim
# tabou
# jalu
# kingman
# newport
# nordborg
# saiha
# nikolayevsk-na-amure
# san andres
# altamont
# puerto colombia
# portland
# sambava
# moratuwa
# keti bandar
# koygorodok
# hof
# adlay
# manzil bu zalafah
# asosa
# laela
# inongo
# jertih
# miri
# dzhusaly
# 404
# {"cod":"404","message":"city not found"}
# kingaroy
# abhar
# morondava
# poykovskiy
# beyneu
# havoysund
# kinshasa
# dhidhdhoo
# dumai
# iwanai
# tono
# sao joao de pirabas
# darovskoy
# dolores
# ankazobe
# ulaangom
# togur
# batetskiy
# chichimila
# porto novo
# lahij
# akyab
# zaida
# magaria
# pangnirtung
# campbell river
# rio grande
# jacareacanga
# kuytun
# port blair
# olinda
# krasnyy chikoy
# kovrov
# puerto maldonado
# ugoofaaru
# jiutai
# kachiry
# sangar
# mwene-ditu
# palauig
# clarksburg
# palestine
# orlik
# porto belo
# palmer
# wittingen
# galliate
# mayo
# dharchula
# brus laguna
# lengshuitan
# tashtagol
# bitung
# winchester
#                    City Countries   Temp  Humidity  Pressure  Latitude  \
# 0    Severo-Yeniseyskiy        RU  31.10        86      1033   60.3725
# 1               Kavieng        PG  84.94        71      1009   -2.5744
# 2                 Bluff        NZ  50.81        77      1030  -46.6000
# 3                Bethel        US  66.88        18      1027   41.3712
# 4              Lüderitz        NA  59.02        61      1016  -26.6481
# ..                  ...       ...    ...       ...       ...       ...
# 691         Brus Laguna        HN  82.26        75      1011   15.7500
# 692         Lengshuitan        CN  61.05        93      1012   26.4111
# 693           Tashtagol        RU  34.92        43      1026   52.7657
# 694              Bitung        ID  76.05        84      1009    1.4451
# 695          Winchester        GB  53.87        80      1010   51.0651
#
#      Longitude
# 0      93.0408
# 1     150.7967
# 2     168.3333
# 3     -73.4140
# 4      15.1594
# ..         ...
# 691   -84.4833
# 692   111.5956
# 693    87.8894
# 694   125.1824
# 695    -1.3187
#
# [696 rows x 7 columns]

# %%
df.to_csv("WeatherPy_Database.csv", index=False)
